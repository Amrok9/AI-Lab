# %% [markdown]
# ### **Dimensionality Reduction with t-SNE**
#  **Goal:** Use t-SNE to visualize high-dimensional data in 2D and understand group structures in complex datasets.

# %% [markdown]
# **Load or Simulate High-Dimensional Data**

# %%
from sklearn.datasets import load_digits
import pandas as pd
import numpy as np

# Load dataset (64-dimensional features from 8x8 digit images)
digits = load_digits()
X = digits.data        # shape = (1797, 64)
y = digits.target      # digit labels (0–9)

print("Shape of X:", X.shape)
# Out:
# Shape of X: (1797, 64)

# %% [markdown]
# **Apply t-SNE for Dimensionality Reduction**

# %%
from sklearn.manifold import TSNE

# Apply t-SNE to reduce to 2D
tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, random_state=42)
X_tsne = tsne.fit_transform(X)

print("Shape after t-SNE:", X_tsne.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Shape after t-SNE: (1797, 2)

# %% [markdown]
# **Visualize 2D Embeddings**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a DataFrame for plotting
df_tsne = pd.DataFrame({
    'x': X_tsne[:, 0],
    'y': X_tsne[:, 1],
    'label': y
})

# Scatter plot colored by digit
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_tsne, x='x', y='y', hue='label', palette='tab10', s=50)
plt.title("t-SNE Visualization of Digit Embeddings (2D)")
plt.legend(title="Digit")
plt.grid(True)
plt.show()

# %% [markdown]
# **(Optional): 3D Visualization with t-SNE**

# %%
from mpl_toolkits.mplot3d import Axes3D

# Run t-SNE for 3D
tsne_3d = TSNE(n_components=3, perplexity=30, n_iter=1000, random_state=42)
X_3d = tsne_3d.fit_transform(X)

# Plot in 3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_3d[:, 0], X_3d[:, 1], X_3d[:, 2], c=y, cmap='tab10', s=50)
ax.set_title("t-SNE 3D Visualization")
legend = ax.legend(*scatter.legend_elements(), title="Digit")
ax.add_artist(legend)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# ### **📌 Summary:**
# 📊 Used the Digits dataset (64 features per image) to visualize handwritten digits.
#
# 🔻 Applied t-SNE to reduce high-dimensional data to 2D and 3D for better understanding.
#
# 🎯 t-SNE preserved the local structure of data, making similar digits appear close together in the plots.
#
# 🌀 Visualized the result using scatter plots colored by digit labels to observe natural groupings.
#
# 🧠 This is an unsupervised learning technique — the model learned structure without using any labels during training.
